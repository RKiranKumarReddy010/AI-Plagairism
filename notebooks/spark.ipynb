# %%
! Pyspark --version
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.2.0
#       /_/
#
# Using Scala version 2.13.18, OpenJDK 64-Bit Server VM, 17.0.19
# Branch HEAD
# Compiled by user hgao on 2026-07-11T15:29:54Z
# Revision 32f7299601108917fb01920a54e084595b7b3bf8
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
from pyspark.sql import SparkSession
#Created a session

# %%
spark =  SparkSession.builder.appName("Analyst").getOrCreate()

# %%
df = spark.read.csv("data/FC26_20250921.csv", header=True, inferSchema=True)

# %%
df.show()
# Out:
# +---------+--------------------+------------+-----------+----------------+-------------------+--------------------+----------------+-------+---------+---------+--------+---+----------+---------+---------+---------+-------------------+------------+------------+-------------------+-------------+------------------+----------------+----------------+------------------------------+--------------+----------------+--------------+---------------+--------------------+--------------+---------+-----------+------------------------+---------+----------------+---------+------------------+--------------------+--------------------+----+--------+-------+---------+---------+------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------
# ...

# %%
df = df.repartition(3)

# %%
print(df.rdd.getNumPartitions())
# Out:
# ---------------------------------------------------------------------------
# PySparkNotImplementedError                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(df.rdd.getNumPartitions())
#
# File c:\Users\KiranKumar\Documents\ColabVM\venv\lib\site-packages\pyspark\sql\connect\dataframe.py:2419, in DataFrame.rdd(self)
#    2417 @property
#    2418 def rdd(self) -> "RDD[Row]":
# -> 2419     raise PySparkNotImplementedError(
#    2420         errorClass="NOT_IMPLEMENTED",
#    2421         messageParameters={"feature": "rdd"},
#    2422     )
#
# PySparkNotImplementedError: [NOT_IMPLEMENTED] rdd is not implemented.
